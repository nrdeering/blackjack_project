# %%
import random
from IPython.display import clear_output

suits = ('Hearts', 'Diamonds', 'Spades', 'Clubs')
ranks = ('Two', 'Three', 'Four', 'Five', 'Six', 'Seven', 'Eight', 'Nine', 'Ten', 'Jack', 'Queen', 'King', 'Ace')
values = {'Two':2, 'Three':3, 'Four':4, 'Five':5, 'Six':6, 'Seven':7, 'Eight':8, 'Nine':9, 'Ten':10, 'Jack':10,
         'Queen':10, 'King':10, 'Ace':11}

playing = True

# %%
# A Card object really only needs two attributes: suit and rank. 
# You might add an attribute for "value" - we chose to handle value later when developing our Hand class.
# In addition to the Card's __init__ method, consider adding a __str__ method that, 
# when asked to print a Card, returns a string in the form "Two of Hearts"

class Card:
    
    def __init__(self, suit, rank):
        self.suit = suit
        self.rank = rank
        self.value = values[rank]
        
    def __str__(self):
        return self.rank + " of " + self.suit

# %%
class Deck:
    
    def __init__(self):
        self.deck = []  # start with an empty list
        for suit in suits:
            for rank in ranks:
                self.deck.append(Card(suit,rank))
    
    def __str__(self):
        
        deck_comp = ''  # start with an empty string
        for card in self.deck:
            deck_comp += '\n '+card.__str__() # add each Card object's print string
        return 'The deck has:' + deck_comp

    def shuffle(self):
        random.shuffle(self.deck)
        
    def deal(self):
        single_card = self.deck.pop()
        return single_card

# %%
class Hand:
    def __init__(self):
        self.cards = []  # start with an empty list as we did in the Deck class
        self.value = 0   # start with zero value
        self.aces = 0    # add an attribute to keep track of aces
    
    def add_card(self,card):
        self.cards.append(card)
        self.value += values[card.rank]
    
    def adjust_for_ace(self):
        pass

# %%
class Chips:
    
    def __init__(self):
        self.total = 1000  # This can be set to a default value or supplied by a user input
        self.bet = 0
        self.betting_pot = 0
        
    def win_bet(self):
        self.total += self.bet
    
    def lose_bet(self):
        self.total -= self.bet

# %%
def take_bet(player_chips,pot):
    
    while player_chips.total > 0:
        try:
            bet = int(input(f'Please enter a number less than or equal to your chip count of ${player_chips.total}: '))
            try:
                if bet <= player_chips.total:
                    print('_____________________')
                    print(f"You have made a bet of ${bet}!")
                    if bet == player_chips.total:
                        print("You are all in!")
                    player_chips.total = player_chips.total - bet

                    pot.betting_pot += bet
                    
                    print(f'The pot is at ${pot.betting_pot}.')
                    return pot.betting_pot
                
                    
                    break
                else:
                    print(f"You don't have enough chips for your bet! You only have ${player_chips.total} in chips.") 
            except:
                pass
        except:
            print("Please enter a valid chip amount.")
    else:
        print("You are out of chips!")

# %%
#take_bet(player_chips, dealer_chips)

# %%
# dealer_chips = Chips()
# player_chips = Chips()

# player_chips.total

# %%
# print(dealer.value)
# print(player.value)

# %%
def hit(deck,player):
     
    if player.value < 21:
        player.add_card(deck.deal())
    else:
        pass

# %%
#hit(test_deck,test_player)

# %%
def hit_or_stand(deck,player):
     
    global playing # to control an upcoming while loop
    playing = True
    
    while playing == True:
        try:
            turn_entry = str(input('Hit or Stand?'))
            try:
                if turn_entry == 'Hit':
                    print(f"You have chosen to hit!.")
                    hit(deck,player)
                    break
                elif turn_entry == 'Stand': 
                    print(f"You have chosen to stand!.")
                    playing = False
                else:
                    print('Please choose Hit or Stand')
            except:
                pass
        except:
            print('Please choose Hit or Stand')

# %%
#hit_or_stand(deck,player)

# %%
def show_some(player,dealer):
    
    print('Player cards: ')
    for card in player.cards:
        print(card)
    print(f'Total value: {player.value}')
    
    print('_____________________')
    
    print('Dealer card: ')
    print(player.cards[1])
    print(f'Total value: {player.cards[1].value}')
    
def show_all(player,dealer):
    
    print('Your cards: ')
    for card in player.cards:
        print(card)
    print(f'Total value: {player.value}')
    
    print('_____________________')
    
    print('Dealer card: ')
    for card in dealer.cards:
        print(card)
    print(f'Total value: {dealer.value}')

# %%
def player_busts():

    if player.value > 21:
        print("You have busted!")
        #dealer_chips.total = dealer_chips.total + pot.betting_pot
        pot.betting_pot = pot.betting_pot - pot.betting_pot
        
def player_wins():

    if player.value <= 21 and player.value > dealer.value:
        print("You won!")
        player_chips.total = player_chips.total + pot.betting_pot
        pot.betting_pot = pot.betting_pot - pot.betting_pot
        
def dealer_busts():

    if dealer.value > 21:
        print("Dealer has busted!")
        player_chips.total = player_chips.total + pot.betting_pot
        pot.betting_pot = pot.betting_pot - pot.betting_pot
        
def dealer_wins():

    if dealer.value<= 21 and dealer.value >= player.value:
        print("Dealer won!")
        #dealer_chips.total = dealer_chips.total + pot.betting_pot
        pot.betting_pot = pot.betting_pot - pot.betting_pot
        
def push():
    pass

# %%
def gameon_choice():
    
    choice = 'wrong'
    
    while choice not in ['Y','N']:
    
        choice = input("Keep playing? (Y or N): ")
        
        if choice not in ['Y','N']:
            print("Sorry, I don't understand, please choose Y or N ")
    
    if choice == 'Y':
        return True
    else:
        return False

# %%
game_on = True

# Set up the Player's chips
player_chips = Chips()
pot = Chips()

print("Welcome to Black Jack! Let's begin...")

while game_on:
    playing = True

    # Create & shuffle the deck, deal two cards to each player
    deck = Deck()
    deck.shuffle()

    dealer = Hand()
    player = Hand()

    dealer.add_card(deck.deal())
    player.add_card(deck.deal())
    dealer.add_card(deck.deal())
    player.add_card(deck.deal())
        
    print(f'You have ${player_chips.total} in chips. ')
    
    # Prompt the Player for their bet
    take_bet(player_chips,pot)
    
    # Show cards (but keep one dealer card hidden)
    print('_____________________')
    show_some(player,dealer)
    
    while playing:  # recall this variable from our hit_or_stand function
        
        # Prompt for Player to Hit or Stand
        hit_or_stand(deck,player)     
        
        # Show cards (but keep one dealer card hidden)
        clear_output()
        print('_____________________')
        show_some(player,dealer) 

        # If player's hand exceeds 21, run player_busts() and break out of loop
        if player.value > 21:
            player_busts()
            playing = False
        else:
            pass

    # If Player hasn't busted, play Dealer's hand until Dealer reaches 17
    while dealer.value < 17 and player.value <= 21:
        dealer.add_card(deck.deal())
        
    # Show all cards
    print('_____________________')
    clear_output()
    show_all(player,dealer)
        
    # Run different winning scenarios
    print('_____________________')   
    
    player_wins()

    dealer_busts()
        
    if player.value <= 21:
        dealer_wins() 
    else:
        print('Dealer wins! You have busted!')
    
    # Inform Player of their chips total 
    
    print(f'Your chip count: {player_chips.total}')
    
    if player_chips.total <= 0:
        print("Game Over! No more chips!")
        break
    # Ask to play again
    game_on = gameon_choice()
# Out:
# Your cards:
# Ace of Diamonds
# Four of Spades
# King of Hearts
# Total value: 25
# _____________________
# Dealer card:
# Seven of Diamonds
# Two of Spades
# Total value: 9
# _____________________
# Dealer wins! You have busted!
# Your chip count: 0
# Game Over! No more chips!
